# %% [markdown]
# <a href="https://colab.research.google.com/github/ahcamachod/2145-data-science-probando-relaciones-con-regresion-lineal/blob/proyecto-final/precios_de_inmuebles_regresion_lineal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***
# #🐧 <font color=#56B4E9 size=6>**Articulo_1: DevOps: una guía para la cultura de desarrollo y operaciones**</font>
# ***

# %% [markdown]
# El articulo completo se encuentra en el siguiente enlace:
#
# [DevOps: una guía para la cultura de desarrollo y operaciones](https://www.aluracursos.com/blog/devops-una-guia-sobre-cultura-del-desarrollo-y-operaciones)

# %% [markdown]
# ***
# #🐧 <font color=#56B4E9 size=6>**Articulo_2: Nube: qué es, historia y guía de la computación en la nube**</font>
# ***

# %% [markdown]
# El articulo completo se encuentra en el siguiente enlace:
#
# [Nube: qué es, historia y guía de la computación en la nube](https://www.aluracursos.com/blog/cloud-historia-y-guia-de-la-computacion-en-la-nube)

# %% [markdown]
# ***
# #🌐🖧🏠 🔗📡<font color=#56B4E9 size=6>🌐🖧🏠 🔗📡**Redes: Introducción, Conceptos y Práctica**</font>
# ***

# %% [markdown]
# ## 🖥️🖨️🖲️ 🛜 🔌 📶 <font color=green size=6> 🖥️🖨️🖲️ 🛜 🔌 📶  **2 DNS, Hubs y cables de conexión**</font>
# ***

# %% [markdown]
# ### 📄 📨 🚦⬆️⬇️ <font color=green size=6>📄 📨 🚦⬆️⬇️ **2.1 Red con 2 equipos**</font>
# ***

# %% [markdown]
# rede en packet tracer CISCO
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# como funciona el ping a la direccion de mi PC
#
# ping 1270.0.0.1
#
#
#
# ```
# # Tiene formato de código
# Microsoft Windows [Versión 10.0.19045.5131]
# (c) Microsoft Corporation. Todos los derechos reservados.
#
# C:\Users\Leonard E Espejo M>ping 127.0.0.1
#
# Haciendo ping a 127.0.0.1 con 32 bytes de datos:
# Respuesta desde 127.0.0.1: bytes=32 tiempo<1m TTL=128
# Respuesta desde 127.0.0.1: bytes=32 tiempo<1m TTL=128
# Respuesta desde 127.0.0.1: bytes=32 tiempo<1m TTL=128
# Respuesta desde 127.0.0.1: bytes=32 tiempo<1m TTL=128
#
# Estadísticas de ping para 127.0.0.1:
#     Paquetes: enviados = 4, recibidos = 4, perdidos = 0
#     (0% perdidos),
# Tiempos aproximados de ida y vuelta en milisegundos:
#     Mínimo = 0ms, Máximo = 0ms, Media = 0ms
#
# C:\Users\Leonard E Espejo M>
# ```

# %% [markdown]
# ahora el comando
#
# ping localhost
#
#
#
# ```
# # Tiene formato de código
# Microsoft Windows [Versión 10.0.19045.5131]
# (c) Microsoft Corporation. Todos los derechos reservados.
#
# C:\Users\Leonard E Espejo M>ping LocalHost
#
# Haciendo ping a DESKTOP-H191QT7 [::1] con 32 bytes de datos:
# Respuesta desde ::1: tiempo<1m
# Respuesta desde ::1: tiempo<1m
# Respuesta desde ::1: tiempo<1m
# Respuesta desde ::1: tiempo<1m
#
# Estadísticas de ping para ::1:
#     Paquetes: enviados = 4, recibidos = 4, perdidos = 0
#     (0% perdidos),
# Tiempos aproximados de ida y vuelta en milisegundos:
#     Mínimo = 0ms, Máximo = 0ms, Media = 0ms
#
# C:\Users\Leonard E Espejo M>
# ```

# %% [markdown]
# vamos e revisar la carpeta local host del sistrema operaqtivo
#
#
#
# ```
# # Tiene formato de código
# C:\Windows\System32\drivers\etc
# ```
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Ete es el archivo de texto
#
#
#
# ```
# # Tiene formato de código
# # Copyright (c) 1993-2009 Microsoft Corp.
# #
# # This is a sample HOSTS file used by Microsoft TCP/IP for Windows.
# #
# # This file contains the mappings of IP addresses to host names. Each
# # entry should be kept on an individual line. The IP address should
# # be placed in the first column followed by the corresponding host name.
# # The IP address and the host name should be separated by at least one
# # space.
# #
# # Additionally, comments (such as these) may be inserted on individual
# # lines or following the machine name denoted by a '#' symbol.
# #
# # For example:
# #
# #      102.54.94.97     rhino.acme.com          # source server
# #       38.25.63.10     x.acme.com              # x client host
#
# # localhost name resolution is handled within DNS itself.
# #	127.0.0.1       localhost
# #	::1             localhost
#
# ```

# %% [markdown]
# Cambiando el nombre localhost y epor una URL
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# revisando el ping a la url local
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 🏗️🧱✉️🔒 🚫 🛑<font color=green size=6>🏗️🧱✉️🔒 🚫 🛑**2.2 Servidor DNS**</font>
# ***

# %% [markdown]
# ¿Cuál es la función del servidor DNS?
# <br />
# ✅
#
# Alternativa correta
# Traducir URLs a direcciones IP.
#
#
# ¡Alternativa correcta! Así es; la función del servidor DNS es la de mapear la dirección IP a un nombre de dominio.

# %% [markdown]
# ¿Cuál es la función del servidor DNS?
# <br />
# ❎
#
# Alternativa incorreta
# Traducir direcciones IP a direcciones de broadcast.
#
#
# ¡Alternativa incorrecta! Esta definición es incorrecta.

# %% [markdown]
# ¿Cuál es la función del servidor DNS?
# <br />
# ❎
#
# Alternativa incorreta
# Traducir direcciones IP a direcciones MAC.
#
#
# ¡Alternativa incorrecta! Esta definición es incorrecta.

# %% [markdown]
# ### 📄 📨 🚦⬆️⬇️ <font color=green size=6>📄 📨 🚦⬆️⬇️ **2.3 Nslookup**</font>
# ***

# %% [markdown]
# EL comando nslookup
#
# ```
# # Tiene formato de código
#
# Microsoft Windows [Versión 10.0.19045.5131]
# (c) Microsoft Corporation. Todos los derechos reservados.
#
# C:\Users\Leonard E Espejo M>nslookup www.google.com
# Servidor:  UnKnown
# Address:  192.168.0.1
#
# Respuesta no autoritativa:
# Nombre:  www.google.com
# Addresses:  2800:3f0:4005:41c::2004
#           172.217.162.132
#
#
# C:\Users\Leonard E Espejo M>
# ```

# %% [markdown]
# EL comnado nslookup con la ip del sistio google
#
#
#
# ```
# # Tiene formato de código
# Microsoft Windows [Versión 10.0.19045.5131]
# (c) Microsoft Corporation. Todos los derechos reservados.
#
# C:\Users\Leonard E Espejo M>nslookup 172.217.162.132
# Servidor:  UnKnown
# Address:  192.168.0.1
#
# Nombre:  gru14s19-in-f4.1e100.net
# Address:  172.217.162.132
#
#
# C:\Users\Leonard E Espejo M>
# ```

# %% [markdown]
# ### 🏗️🧱✉️🔒 🚫 🛑<font color=green size=6>🏗️🧱✉️🔒 🚫 🛑**2.4 El Nslookup**</font>
# ***

# %% [markdown]
# ¿Cuál es el uso principal del Nslookup?
# <br />
# ✅
#
# Alternativa correta
# Verificar la traducción de nombres de dominios y direcciones IP e isolar problemas entre las dos partes.
#
#
# ¡Alternativa correcta! Nslookup puede ser usado para descubrir la dirección IP de un domínio, o para conocer si nuestro servicio está siendo dirigido hacia la máquina de destino, por ejemplo.

# %% [markdown]
# ¿Cuál es el uso principal del Nslookup?
# <br />
# ❎
# Alternativa incorreta
# Descubrir quién es el administrador de un dominio.
#
#
# ¡Alternativa incorrecta! Esta no es la función de nslookup.

# %% [markdown]
# ¿Cuál es el uso principal del Nslookup?
# <br />
# ❎
# Alternativa incorreta
# Descubrir dónde el dominio se encuentra localizado.
#
#
# ¡Alternativa incorrecta! Esta no es la función de nslookup.

# %% [markdown]
# ### 📄 📨 🚦⬆️⬇️ <font color=green size=6>📄 📨 🚦⬆️⬇️ **2.1 Red con 3 equipos**</font>
# ***

# %% [markdown]
# Red de tres computadores
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 🏗️🧱✉️🔒 🚫 🛑<font color=green size=6>🏗️🧱✉️🔒 🚫 🛑**2.6 Conexión entre varios PCs**</font>
# ***

# %% [markdown]
# ¿Cuál equipo podemos usar para conectar varios computadores?
#
# Seleccione una alternativa
#
# <br />
# ✅
#
# Alternativa correta
#
# Hub
#
#
# ¡Alternativa correcta! El Hub es un equipo que nos permite conectar varios dispositivos finales.

# %% [markdown]
# ¿Cuál equipo podemos usar para conectar varios computadores?
#
# Seleccione una alternativa
# <br />
# ❎
# Alternativa incorreta
# Nat
#
# ¡Alternativa incorrecta! Este es un método de traducción de direcciones IP privadas a direcciones IP públicas.

# %% [markdown]
# ¿Cuál equipo podemos usar para conectar varios computadores?
#
# Seleccione una alternativa
# <br />
# ❎
# Alternativa incorreta
# Servidor
#
# ¡Alternativa incorrecta! Un servidor es una máquina centralizada que ofrece servicios a un cliente (Computador).

# %% [markdown]
# ### 📄 📨 🚦⬆️⬇️ <font color=green size=6>📄 📨 🚦⬆️⬇️ **2.7 Cables de conexión**</font>
# ***

# %% [markdown]
# **texto en negrita**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 🏗️🧱✉️🔒 🚫 🛑<font color=green size=6>🏗️🧱✉️🔒 🚫 🛑**2.8 Tipos de cables**</font>
# ***

# %% [markdown]
# ¿Cuáles son los dos tipos de cables que empleamos para la conexión en este video?
#
# Seleccione una alternativa
#
# <br />
# ✅
#
# Alternativa correta
# Cable directo y cable cruzado.
#
#
# ¡Alternativa correcta! En caso que sigamos el mismo patrón de colores en los dos extremos del cable, lo llamamos cable directo, Pues la misma secuencia de colores se repite en las 2 puntas.
#
# En caso que tengamos una secuencia diferente de colores, se trata de un cable cruzado.

# %% [markdown]
# ¿Cuáles son los dos tipos de cables que empleamos para la conexión en este video?
#
# Seleccione una alternativa
# <br />
# ❎
# Alternativa incorreta
# Cable azul y cable rojo.
#
#
# ¡Alternativa incorrecta! Esta respuesta no corresponde.

# %% [markdown]
# ¿Cuáles son los dos tipos de cables que empleamos para la conexión en este video?
#
# Seleccione una alternativa
# <br />
# ❎
# Alternativa incorreta
# Cable directo y cable a rayas.
#
#
# ¡Alternativa incorrecta! Esta respuesta no corresponde.

# %% [markdown]
# ### 📄 📨 🚦⬆️⬇️ <font color=green size=6>📄 📨 🚦⬆️⬇️ **2.9 Estándares TIA**</font>
# ***

# %% [markdown]
# ¿Cuáles son los dos tipos de estandar TIA?
#
# Seleccione una alternativa
#
# <br />
# ✅
#
# Alternativa correta
# CT568A y T568B.
#
#
# ¡Alternativa correcta! T568A posee la siguiente secuencia de colores: Blanco y verde, verde, blanco y anaranjado, azul, blanco y azul, anaranjado, blanco y marrón, marrón. T568B: Blanco y anaranjado, anaranjado, blanco y verde, azul, blanco y azul, verde, blanco y marrón, marrón.

# %% [markdown]
# ¿Cuáles son los dos tipos de estandar TIA?
#
# Seleccione una alternativa
#
# <br />
# ❎
# Alternativa incorreta
#
# T568X y T568P.
#
#
# ¡Alternativa incorrecta! Esta respuesta no corresponde.

# %% [markdown]
# ¿Cuáles son los dos tipos de cables que empleamos para la conexión en este video?
#
# Seleccione una alternativa
# <br />
# ❎
# Alternativa incorreta
# Cable directo y cable a rayas.
#
#
# ¡Alternativa incorrecta! Esta respuesta no corresponde.

# %% [markdown]
# ¿Cuáles son los dos tipos de estandar TIA?
#
# Seleccione una alternativa
#
# <br />
# ❎
# Alternativa incorreta
#
# T5877 y T5866.
#
#
# ¡Alternativa incorrecta! Esta respuesta no corresponde.

# %% [markdown]
# ### 🏗️🧱✉️🔒 🚫 🛑<font color=green size=6>🏗️🧱✉️🔒 🚫 🛑**2.10 Haga lo que hicimos en aula**</font>
# ***

# %% [markdown]
# Llegó la hora de que sigas todos los pasos realizados por mí durante esta clase. Si ya lo has hecho ¡Excelente! Si todavía no lo has hecho, es importante que ejecutes lo que fue visto en los vídeos para que puedas continuar con la próxima aula.
#
# 1) Abre Packet Tracer, selecciona dos dispositivos finales y los interconectas con un cable cruzado como se muestra a continuación:
#
# 23.png
#
# 2) Ahora selecciona el PC0 y da click en la pestaña Desktop así:
#
# 24.png
#
# 3) Ahora haz click en el ícono de IP Configuration y digita la dirección IP 192.168.0.2, con la máscara 255.255.255.0, como se muestra a continuación:
#
# 25.png
#
# 4) Repite los pasos 2 y 3 en el PC1, pero digitando la dirección IP 192.168.0.3. Debe quedar así:
#
# 26.png
#
# 5) Entra nuevamente al PC0, haciendo clic sobre él, y en la pestaña Desktop selecciona la opción Command Prompt. Accederás al símbolo del sistema del PC0:
#
# 27.png
#
# 6) Digita el siguiente comando: ping 192.168.0.3. El output será semejante al que se muestra a continuación:
#
# 28.png
#
# 7) ¡Felicitaciones! Haz conectado con éxito dos dispositivos finales.
#
# 8) Ahora, vamos a acceder al símbolo del sistema de nuestra máquina (No en Packet Tracer), y emplearemos el comando nslookup www.google.com para conocer la dirección IP del servidor de google. El output nos mostrará las direcciones IPv4 e IPv6 del servidor de google al cual nos estamos conectando:
#
# 29.png
#
# 9) También, haremos uso del comando nslookup 142.250.79 para verificar que el servicio está funcionando correctamente en ambos sentidos, es decir, si colocamos la dirección IP, nos debe mostrar una URL asociada. (Es normal que, por motivos de seguridad, google no muestre su nombre de dominio):
#
# 30.png
#
# 10) retornaremos a Packet Tracer y añadiremos un nuevo dispositivo final, al cual le asignaremos la dirección IP 192.168.0.254 (siguiendo los pasos 1 y 2). Eliminamos el cable cruzado que interconecta PC0 y PC1, y adicionamos un Hub-PT, haciendo la selección como se muestra a continuación:
#
# 31.png
#
# 32.png
#
# 11) Conectamos todos los dispositivos finales al Hub-PT utilizando cables directos (Copper straight-through):
#
# 33.png
#
# 12) Por último, hacemos ping desde el PC2 al PC0, utilizando el command prompt del PC2 y el siguiente comando: ping 192.168.0.2:
#
# 34.png
#
# 13) ¡Muy bien! Has conectado con éxito 3 computadores en red a través de un Hub.
#
# Ver opinión del instructor
# Opinión del instructor
#
# Continúa con tus estudios, y en caso de dudas, no olvides acudir a nuestro foro.

# %% [markdown]
# Haga lo que hicimos en aula
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# practicando NSLOOKUP
#
#
#
# ```
# # Tiene formato de código
# Microsoft Windows [Versión 10.0.19045.5131]
# (c) Microsoft Corporation. Todos los derechos reservados.
#
# C:\Users\Leonard E Espejo M>nslookup www.google.com.co
# Servidor:  UnKnown
# Address:  192.168.0.1
#
# Respuesta no autoritativa:
# Nombre:  www.google.com.co
# Addresses:  2800:3f0:4005:418::2003
#           142.251.129.195
#
#
# C:\Users\Leonard E Espejo M>nslookup 142.251.129.195
# Servidor:  UnKnown
# Address:  192.168.0.1
#
# Nombre:  ncboga-ad-in-f3.1e100.net
# Address:  142.251.129.195
#
#
# C:\Users\Leonard E Espejo M>
#
# ```

# %% [markdown]
# ### 📄 📨 🚦⬆️⬇️ <font color=green size=6>📄 📨 🚦⬆️⬇️ **2.11 Lo que aprendimos**</font>
# ***

# %% [markdown]
# Lo que aprendimos en esta aula:
#
# - A crear una red con 2 equipos utilizando Packet Tracer.
# - A configurar direcciones IP de forma estática.
# - A utilizar Nslookup.
# - Conexiones entre varios equipos utilizando un Hub.
# - Los tipos de cable para la conexión de los diversos equipos.

# %% [markdown]
# #CAMBIAR
