# %% [markdown]
# <a href="https://colab.research.google.com/github/ahcamachod/2145-data-science-probando-relaciones-con-regresion-lineal/blob/proyecto-final/precios_de_inmuebles_regresion_lineal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***
# #🐧 <font color=#56B4E9 size=6>**Articulo_1: DevOps: una guía para la cultura de desarrollo y operaciones**</font>
# ***

# %% [markdown]
# El articulo completo se encuentra en el siguiente enlace:
#
# [DevOps: una guía para la cultura de desarrollo y operaciones](https://www.aluracursos.com/blog/devops-una-guia-sobre-cultura-del-desarrollo-y-operaciones)

# %% [markdown]
# ***
# #🐧 <font color=#56B4E9 size=6>**Articulo_2: Nube: qué es, historia y guía de la computación en la nube**</font>
# ***

# %% [markdown]
# El articulo completo se encuentra en el siguiente enlace:
#
# [Nube: qué es, historia y guía de la computación en la nube](https://www.aluracursos.com/blog/cloud-historia-y-guia-de-la-computacion-en-la-nube)

# %% [markdown]
# ***
# #🌐🖧🏠 🔗📡<font color=#56B4E9 size=6>🌐🖧🏠 🔗📡**Redes: Introducción, Conceptos y Práctica**</font>
# ***

# %% [markdown]
# ## 🖥️🖨️🖲️ 🛜 🔌 📶 <font color=green size=6> 🖥️🖨️🖲️ 🛜 🔌 📶**6.Accediendo a la web con Packet Tracer**</font>
# ***

# %% [markdown]
# ### 📄 📨 🚦⬆️⬇️ <font color=green size=6>📄 📨 🚦⬆️⬇️ **6.1 Conexión con Google**</font>
# ***

# %% [markdown]
# CONFIGURACION DEL ROUTER CON EL SW DE WAN
#
# <b />
#
# ```
# # Tiene formato de código
# Router>enable
# Router#conf
# Router#configure
# Configuring from terminal, memory, or network [terminal]? terminal
# Enter configuration commands, one per line.  End with CNTL/Z.
# Router(config)#interf
# Router(config)#interface fast
# Router(config)#interface fastEthernet 0/1
# Router(config-if)#no sh
# Router(config-if)#no shutdown
#
# Router(config-if)#
# %LINK-5-CHANGED: Interface FastEthernet0/1, changed state to up
#
# %LINEPROTO-5-UPDOWN: Line protocol on Interface FastEthernet0/1, changed state to up
#
# Router(config-if)#ip adde
# Router(config-if)#ip add
# Router(config-if)#ip address 75.25.50.1 255.0.0.0
# Router(config-if)#exit
# Router(config)#exit
# Router#
# %SYS-5-CONFIG_I: Configured from console by console
#
# Router#
# ```

# %% [markdown]
# CONFIGURACION DEL SERVIDOR
# <b />
#
#
#
# ```
# # Tiene formato de código
#
# Cisco Packet Tracer SERVER Command Line 1.0
#
# Cisco Packet Tracer SERVER Command Line 1.0
# C:\>ipconfig /all
#
# FastEthernet0 Connection:(default port)
#
#    Connection-specific DNS Suffix..:
#    Physical Address................: 0006.2A09.08EE
#    Link-local IPv6 Address.........: FE80::206:2AFF:FE09:8EE
#    IPv6 Address....................: ::
#    IPv4 Address....................: 75.255.255.254
#    Subnet Mask.....................: 255.0.0.0
#    Default Gateway.................: ::
#                                      75.25.50.1
#    DHCP Servers....................: 0.0.0.0
#    DHCPv6 IAID.....................:
#    DHCPv6 Client DUID..............: 00-01-00-01-0E-B1-D2-C8-00-06-2A-09-08-EE
#    DNS Servers.....................: ::
#                                      0.0.0.0
#
#
# C:\>
# C:\>
# ```

# %% [markdown]
# CONFIGURACION DE INDEX DEL SERVER
#
#
#
# ```
# # Tiene formato de código
#
# <html>
# <h1>GOOGLE</h1>
# <input type="search">
# <input type="button" value="Buscar">
# </html>
# ```

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 🏗️🧱✉️🔒 🚫 🛑<font color=green size=6>🏗️🧱✉️🔒 🚫 🛑**6.2 Secuencia de comandos**</font>
# ***

# %% [markdown]
# ¿Cuál es la secuencia de comandos para configurar el servidor DHCP en el router?
#
# Ver opinión del instructor
# Opinión del instructor
#
# En el modo de configuración del router, es decir, router(config)#, digite:
#
#
# ```
# # Tiene formato de código
#
# ip dhcp pool RED_LOCAL
# network 192.168.0.0 255.255.255.0
# default-router 192.168.0.1
# exit
# ```
#
# EN LA CONFIGURACION DELROUTER
#
#
#
# ```
# # Tiene formato de código
# Router(config)# ip dhcp pool RED_LOCAL
# Router(dhcp-config)# network 192.168.0.0 255.255.255.0
# Router(dhcp-config)# default-router 192.168.0.1
# Router(dhcp-config)# exit
# ```

# %% [markdown]
# ### 📄 📨 🚦⬆️⬇️ <font color=green size=6>📄 📨 🚦⬆️⬇️ **6.3 Configurando el DNS**</font>
# ***

# %% [markdown]
# SE INGRESA UN SERVIDOR NUEVO EN LA RED Y SE CONFIGURA Y HABILITA EL SERVIDOR DND PARA LA ip Y LA URL PARA WWW.GOOGLE.COM
# SE CREA LA TABLA
#
# www.google.com  PARA LA iP 75.255.255.254

# %% [markdown]
# OCNFIGURANDO EL ROUTER DANDOLE LA RUTA PARA EL SERVIDOR DHCP GON LA ACTUALIZACION DE GOOGLE
#
#
# ```
# # Tiene formato de código
#
# Press RETURN to get started!
#
#
# %LINEPROTO-5-UPDOWN: Line protocol on Interface FastEthernet0/0, changed state to up
#
# %LINEPROTO-5-UPDOWN: Line protocol on Interface FastEthernet0/1, changed state to up
#
#
# Router>enable
# Router#config
# Router#configure
# Configuring from terminal, memory, or network [terminal]? terminal
# Enter configuration commands, one per line.  End with CNTL/Z.
# Router(config)#ip dhc
# Router(config)#ip dhcp pool
# Router(config)#ip dhcp pool RED_LOCAL
# Router(dhcp-config)#dnss
# Router(dhcp-config)#dns
# Router(dhcp-config)#dns-server 75.75.75.75 ?
#   <cr>
# Router(dhcp-config)#dns-server 75.75.75.75
# Router(dhcp-config)#exit
# Router(config)#
# ```

# %% [markdown]
# SE DEBE ACTUALIZAR CADA PC PARA QUE TOME LOS CAMBIOS DEL SERVIDOPR DND EN EL ROUTER
#
#
#
# ```
# ANTES
# # Tiene formato de código
#
#
# Cisco Packet Tracer PC Command Line 1.0
# C:\>ipconfig /all
#
# FastEthernet0 Connection:(default port)
#
#    Connection-specific DNS Suffix..:
#    Physical Address................: 00E0.F907.127B
#    Link-local IPv6 Address.........: FE80::2E0:F9FF:FE07:127B
#    IPv6 Address....................: ::
#    IPv4 Address....................: 192.168.0.3
#    Subnet Mask.....................: 255.255.255.0
#    Default Gateway.................: ::
#                                      192.168.0.1
#    DHCP Servers....................: 192.168.0.1
#    DHCPv6 IAID.....................:
#    DHCPv6 Client DUID..............: 00-01-00-01-A9-5C-95-36-00-E0-F9-07-12-7B
#    DNS Servers.....................: ::
#                                      0.0.0.0
# ```
#
#
#
# ```
# DESPUES DE ACTUALIZAR EL DHCP
# # Tiene formato de código
#
#
# C:\>ipconfig /all
#
# FastEthernet0 Connection:(default port)
#
#    Connection-specific DNS Suffix..:
#    Physical Address................: 00E0.F907.127B
#    Link-local IPv6 Address.........: FE80::2E0:F9FF:FE07:127B
#    IPv6 Address....................: ::
#    IPv4 Address....................: 192.168.0.3
#    Subnet Mask.....................: 255.255.255.0
#    Default Gateway.................: ::
#                                      192.168.0.1
#    DHCP Servers....................: 192.168.0.1
#    DHCPv6 IAID.....................:
#    DHCPv6 Client DUID..............: 00-01-00-01-A9-5C-95-36-00-E0-F9-07-12-7B
#    DNS Servers.....................: ::
#                                      75.75.75.75
# ```

# %% [markdown]
# EL SERVIDOR DND QQUEDO MAL CONFIGURADO EL DEFAULT GATEWAY NO ES EL CORRECTO
#
#
#
# ```
# ERROR EN EL GATEWAY
# # Tiene formato de código
#
#
# Cisco Packet Tracer SERVER Command Line 1.0
# C:\>ipconfig /all
#
# FastEthernet0 Connection:(default port)
#
#    Connection-specific DNS Suffix..:
#    Physical Address................: 0002.17A0.3A2C
#    Link-local IPv6 Address.........: FE80::202:17FF:FEA0:3A2C
#    IPv6 Address....................: ::
#    IPv4 Address....................: 75.75.75.75
#    Subnet Mask.....................: 255.0.0.0
#    Default Gateway.................: ::
#                                      75.50.25.1
#    DHCP Servers....................: 0.0.0.0
#    DHCPv6 IAID.....................:
#    DHCPv6 Client DUID..............: 00-01-00-01-77-6B-89-C9-00-02-17-A0-3A-2C
#    DNS Servers.....................: ::
#                                      0.0.0.0
# ```
#
#
# ```
# GATEWAY CORREGIDO
# # Tiene formato de código
#
# C:\>
# C:\>ipconfig /all
#
# FastEthernet0 Connection:(default port)
#
#    Connection-specific DNS Suffix..:
#    Physical Address................: 0002.17A0.3A2C
#    Link-local IPv6 Address.........: FE80::202:17FF:FEA0:3A2C
#    IPv6 Address....................: ::
#    IPv4 Address....................: 75.75.75.75
#    Subnet Mask.....................: 255.0.0.0
#    Default Gateway.................: ::
#                                      75.25.50.1
#    DHCP Servers....................: 0.0.0.0
#    DHCPv6 IAID.....................:
#    DHCPv6 Client DUID..............: 00-01-00-01-77-6B-89-C9-00-02-17-A0-3A-2C
#    DNS Servers.....................: ::
#                                      0.0.0.0
# ```

# %% [markdown]
# PRUEBA DE CONFIGURACION YU NAAVEGACION DESDE UN PC EL PC 2
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 🏗️🧱✉️🔒 🚫 🛑<font color=green size=6>🏗️🧱✉️🔒 🚫 🛑**6.4 Configuración del proyecto**</font>
# ***

# %% [markdown]
# Qué configuración hicimos en el proyecto para que fuera posible que los computadores, al digitar www.google.com en el navegador, obtuviesen la página de google en la pantalla?
#
#
# <br />
# ✅
# ¡Alternativa correcta!
# Tuvimos que configurar el servidor DNS en el DHCP del router para atribuir esa dirección del DNS a las máquinas (clientes).
#
#
# ¡Alternativa correcta! Los computadores no saben quién es el servidor DNS; nosotros debemos informarles quién es el servidor que deben buscar.

# %% [markdown]
# Qué configuración hicimos en el proyecto para que fuera posible que los computadores, al digitar www.google.com en el navegador, obtuviesen la página de google en la pantalla?
# <br />
# ❎
# Tuvimos que configurar la IP adecuada.
#
#
# ¡Alternativa incorrecta! Esta respuesta no corresponde

# %% [markdown]
# Qué configuración hicimos en el proyecto para que fuera posible que los computadores, al digitar www.google.com en el navegador, obtuviesen la página de google en la pantalla?
# <br />
# ❎
# No tuvimos que hacer nada.
#
#
# ¡Alternativa incorrecta! Te invito a ver el video una vez más.

# %% [markdown]
# ### 📄 📨 🚦⬆️⬇️ <font color=green size=6>📄 📨 🚦⬆️⬇️ **6.5 Haga lo que hicimos en aula**</font>
# ***

# %% [markdown]
# Llegó la hora de que sigas todos los pasos realizados por mí durante esta clase. Si ya lo has hecho ¡Excelente! Si todavía no lo has hecho, es importante que ejecutes lo que fue visto en los vídeos para que puedas continuar con la próxima aula.
#
# 1) Para nuestro proyecto final, vamos a seleccionar un Switch 2960 y un servidor como dispositivo final (El servidor lo renombraremos como Google). Tomaremos como base la topología del aula anterior:
#
# 64.png
#
# 2) Haremos clic sobre el servidor, y en la pestaña Services, seleccionaremos la opción HTTP:
#
# 65.png
#
# 3) Haremos clic en la opción (edit) de index.html
#
# 66.png
#
# 4) Seleccionamos todo lo que aparece resaltado en la imagen, lo eliminamos y lo sustituimos por el código que aparece en la imagen final. Presionamos Save:
#
# 67.png
#
# 68.png
#
# 69.png
#
# 70.png
#
# 5) Ahora, nos desplazamos a la pestaña Desktop y seleccionamos IP Configuration. Colocamos de forma estática la dirección IP 75.25.50.2 con máscara 255.0.0.0:
#
# 71.png
#
# 6) El siguiente paso es desplazarnos al Router y configurar la interfaz Fast Ethernet 0/1 con los siguientes comandos:
#
# n
# Router> enable
# Router# configure terminal
# Router(config)# interface fastEthernet 0/1
# Router(config-if)# ip address 75.75.75.75 255.0.0.0
# Router(config-if)# no shutdown
# Router(config-if)# exitCopia el código
# 72.png
#
# 7) Volvemos al servidor “Google”, y en la pestaña Desktop, seleccionamos IP Configuration y colocamos el default gateway con la siguiente dirección IP: 75.75.75.75, y el servidor DNS 75.85.95.105:
#
# 73.png
#
# 8) Ahora accedemos al PC1, y en la pestaña Desktop, seleccionamos Web Browser, y digitamos la dirección IP del Servidor, es decir, 75.25.50.2:
#
# 74.png
#
# ¡Muy bien! Has accedido a la página de google desde el PC1.
#
# 9) Desde luego que no accedemos a internet utilizando las direcciones IP de las páginas web, sino utilizamos el nombre del dominio, o URL. Para ello, vamos a proceder a crear y a configurar un servidor DNS. Lo conectaremos al switch de la red externa con un cable directo, y le asignaremos la dirección IP 75.85.95.105 con máscara 255.0.0.0 y lo renombraremos “DNS”, también colocaremos el default gateway como 75.75.75.75:
#
# 75.png
#
# 76.png
#
# 10) Haremos clic sobre el servidor DNS, y en la pestaña Services, seleccionaremos la opción DNS, y colocaremos la información como se muestra en la siguiente imagen. Damos clic en el botón Add:
#
# 77.png
#
# 78.png
#
# 11) Posteriormente, nos dirigimos al Router, y entramos al pool de DHCP que creamos para añadir la dirección IP del servidor DNS de modo que al digitar www.google.com desde cualquier navegador de los computadores de la red privada, podamos acceder a la página de google que creamos. Los comandos en el router son los siguientes:
#
# n
# Router> enable
# Router# configure terminal
# Router(config)# ip dhcp pool RED_LOCAL
# Router(dhcp-config)# dns-server 75.85.95.105
# Router(dhcp-config)# exitCopia el código
# 79.png
#
# 12) Debemos, de igual forma, ir a cada computador seleccionar IP Configuration y colocar static y volver a hacer clic sobre dynamic para restablecer las direcciones IP con el servidor DNS:
#
# 80.png
#
# 81.png
#
# 82.png
#
# 83.png
#
# 13) Finalmente, accederemos al PC1, y en la pestaña Desktop, seleccionamos Web Browser, y digitamos la url www.google.com, y presionamos Enter:
#
# 84.png
#
# ¡Excelente! Has entrado a la página de google digitando la URL en el navegador de uno de los computadores de Packet Tracer.
#
# Ver opinión del instructor
# Opinión del instructor
#
# Continúa con tus estudios, y en caso de dudas, no olvides acudir a nuestro foro.

# %% [markdown]
# ### 🏗️🧱✉️🔒 🚫 🛑<font color=green size=6>🏗️🧱✉️🔒 🚫 🛑**6.7 Lo que aprendimos**</font>
# ***

# %% [markdown]
# Lo que aprendimos en esta aula:
#
# - A crear un servidor con una página web sencilla.
# - A configurar y utilizar un servidor DNS.
# - A simular una conexión cliente-servidor empleando Packet Tracer.

# %% [markdown]
# #CAMBIAR
