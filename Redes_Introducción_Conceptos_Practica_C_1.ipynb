# %% [markdown]
# <a href="https://colab.research.google.com/github/ahcamachod/2145-data-science-probando-relaciones-con-regresion-lineal/blob/proyecto-final/precios_de_inmuebles_regresion_lineal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***
# #🐧 <font color=#56B4E9 size=6>**Articulo_1: DevOps: una guía para la cultura de desarrollo y operaciones**</font>
# ***

# %% [markdown]
# El articulo completo se encuentra en el siguiente enlace:
#
# [DevOps: una guía para la cultura de desarrollo y operaciones](https://www.aluracursos.com/blog/devops-una-guia-sobre-cultura-del-desarrollo-y-operaciones)

# %% [markdown]
# ***
# #🐧 <font color=#56B4E9 size=6>**Articulo_2: Nube: qué es, historia y guía de la computación en la nube**</font>
# ***

# %% [markdown]
# El articulo completo se encuentra en el siguiente enlace:
#
# [Nube: qué es, historia y guía de la computación en la nube](https://www.aluracursos.com/blog/cloud-historia-y-guia-de-la-computacion-en-la-nube)

# %% [markdown]
# ***
# #🌐🖧🏠 🔗📡<font color=#56B4E9 size=6>🌐🖧🏠 🔗📡**Redes: Introducción, Conceptos y Práctica**</font>
# ***

# %% [markdown]
# ## 🖥️🖨️🖲️ 🛜 🔌 📶 <font color=green size=6> 🖥️🖨️🖲️ 🛜 🔌 📶**3 Wireshark, Switches y avances**</font>
# ***

# %% [markdown]
# ### 📄 📨 🚦⬆️⬇️ <font color=green size=6>📄 📨 🚦⬆️⬇️ **3.1 Limitación del Hub**</font>
# ***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 🏗️🧱✉️🔒 🚫 🛑<font color=green size=6>🏗️🧱✉️🔒 🚫 🛑**3.2 Limitaciones del Hub**</font>
# ***

# %% [markdown]
# ¿Cuáles serían dos de las principales limitaciones del Hub?
# <br />
# ✅
#
# Alternativa correta
#
# Seguridad y lentitud.
#
#
# ¡Alternativa correcta! Los hubs no pueden aprender dónde está localizada cada máquina, de esa forma, él reenvía la información para todas las otras máquinas conectadas. Esto quiere decir que en caso se presente flujo intenso de tráfico en la red, Esta información será reenviada a los demás usuarios de la red.

# %% [markdown]
# ¿Cuáles serían dos de las principales limitaciones del Hub?
# <br />
# ❎
# ?
#
# Alternativa incorreta
# Poca memoria y precio de mercado.
#
#
# ¡Alternativa incorrecta! Estos aspectos no fueron mencionados en el video.

# %% [markdown]
# ¿Cuáles serían dos de las principales limitaciones del Hub?
# <br />
# ❎
#
#
# Alternativa incorreta
# No presenta limitaciones.
#
#
# ¡Alternativa incorrecta! El Hub sí posee algunas limitaciones.

# %% [markdown]
# ### 📄 📨 🚦⬆️⬇️ <font color=green size=6>📄 📨 🚦⬆️⬇️ **3.3 Usando Wireshark Numero 1**</font>
# ***

# %% [markdown]
# usar pagians con SSL o el candado en el navegador

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 🏗️🧱✉️🔒 🚫 🛑<font color=green size=6>🏗️🧱✉️🔒 🚫 🛑**3.4 Wireshark**</font>
# ***

# %% [markdown]
# ¿Cuál es la principal funcionalidad del programa Wireshark?
# <br />
# ✅
#
# Alternativa correta
#
# Analizar protocolos para resolver problemas de redes.
#
#
# ¡Alternativa correcta! Este es el objetivo principal de Wireshark.

# %% [markdown]
# ¿Cuál es la principal funcionalidad del programa Wireshark?
# <br />
# ❎
# ?
#
# Alternativa incorreta
# Analizar a las personas que se conectan a nuestro sistema.
#
#
# ¡Alternativa incorrecta! Wireshark no tiene esta finalidad.

# %% [markdown]
# ¿Cuál es la principal funcionalidad del programa Wireshark?
# <br />
# ❎
#
# Descubrir quienes son las personas conectadas a nuestra red.
#
#
# ¡Alternativa incorrecta! Wireshark no tiene esta finalidad.

# %% [markdown]
# ### 📄 📨 🚦⬆️⬇️ <font color=green size=6>📄 📨 🚦⬆️⬇️ **3.5 Usando Wireshark Numero 2**</font>
# ***

# %% [markdown]
# caputuras de wireshark y uso de nslookup
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# mostrando el wireshark para las paginas seguras deben ser encriptadas
#
#
#
# ```
# # Tiene formato de código
#
#
# C:\Users\Leonard E Espejo M>nslookup www.youtube.com
# Servidor:  UnKnown
# Address:  192.168.0.1
#
# Respuesta no autoritativa:
# Nombre:  youtube-ui.l.google.com
# Addresses:  2800:3f0:4005:417::200e
#           2800:3f0:4005:400::200e
#           2800:3f0:4005:41b::200e
#           2800:3f0:4005:41a::200e
#           172.217.162.110
#           172.217.30.206
#           142.251.129.206
#           142.251.132.14
#           142.250.218.206
#           142.251.133.142
#           142.251.133.110
#           142.251.132.174
#           172.217.29.14
#           172.217.30.174
#           172.217.28.110
#           172.217.162.142
# Aliases:  www.youtube.com
#
#
# C:\Users\Leonard E Espejo M>
# ```
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 🏗️🧱✉️🔒 🚫 🛑<font color=green size=6>🏗️🧱✉️🔒 🚫 🛑**3.6 Protocolos y criptografía**</font>
# ***

# %% [markdown]
# ¿Cuál de los siguientes protocolos es empleado para encriptar la información?
# <br />
# ✅
#
# Alternativa correta
#
# TLS
#
#
# ¡Alternativa correcta! TLS (Transport Layer Security) seria un protocolo de criptografía utilizado para la seguridad de la información. Este es la evolución del protocolo SSL (Secure Sockets Layer).

# %% [markdown]
# ¿Cuál de los siguientes protocolos es empleado para encriptar la información?
# <br />
# ❎
# VLAN
#
#
# ¡Alternativa incorrecta! Virtual Local Area Network no es un protocolo sino una red de área local creada de forma lógica.

# %% [markdown]
# ¿Cuál de los siguientes protocolos es empleado para encriptar la información?
# <br />
# ❎
# HTTP
#
#
# ¡Alternativa incorrecta! HTTP es el protocolo de transferencia de hipertexto, y por sí solo no presenta ninguna criptografía.

# %% [markdown]
# ### 📄 📨 🚦⬆️⬇️ <font color=green size=6>📄 📨 🚦⬆️⬇️ **3.7 Switches**</font>
# ***

# %% [markdown]
# - el SW crea la tabla despues de aprender la asociacion de las IP con sus MAC
# - se puede saturar y enviar broadcast
# - se hace TCP IP
# - luego ARP
# - silo encuentra y lo guarda hace
# - tambien hace STP
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 🏗️🧱✉️🔒 🚫 🛑<font color=green size=6>🏗️🧱✉️🔒 🚫 🛑**3.8 Hubs vs. Switches**</font>
# ***

# %% [markdown]
# ¿Cuál es la principal diferencia entre los Hubs y los Switches?
#
# Seleccione una alternativa
# <br />
# ✅
#
# Alternativa correcta
#
# El Hub no logra aprender donde un equipo se encuentra localizado. El Switch sí.
#
#
# ¡Alternativa correcta! Los switches aprenden y almacenan las direcciones MAC de los equipos conectados en su red.

# %% [markdown]
# ¿Cuál es la principal diferencia entre los Hubs y los Switches?
# <br />
# ❎
# Ambos equipos no poseen diferencias significativas.
#
#
# ¡Alternativa incorrecta! Esta respuesta no corresponde.

# %% [markdown]
# ¿Cuál es la principal diferencia entre los Hubs y los Switches?
# <br />
# ❎
# Memoria RAM.
#
#
# ¡Alternativa incorrecta! Esta respuesta no corresponde.

# %% [markdown]
# ### 📄 📨 🚦⬆️⬇️ <font color=green size=6>📄 📨 🚦⬆️⬇️ **3.9 Switches**</font>
# ***

# %% [markdown]
# ¿Cómo un switch aprende dónde un equipo está localizado?
#
# Seleccione una alternativa
# <br />
# ✅
#
# Alternativa correta
# Cuando un dispositivo se quiere comunicar con otro, la información que se envía a través de una PDU va a pasar por el Switch. Este PDU contiene al interior su dirección MAC de origen y así, el Switch almacena esta información en su memoria.
#
#
# ¡Alternativa correcta! Los switches aprenden de esta manera y reconocen la interfaz por la cual está conectado el equipo con su respectiva dirección MAC.

# %% [markdown]
# ¿Cómo un switch aprende dónde un equipo está localizado?
#
# Seleccione una alternativa
# <br />
# ❎
# El Switch pregunta al servidor, y este servidor le envía la información sobre los dispositivos que se encuentran conectados a su red.
#
#
# ¡Alternativa incorrecta! Esta respuesta no corresponde.

# %% [markdown]
# ¿Cómo un switch aprende dónde un equipo está localizado?
#
# Seleccione una alternativa
# <br />
# ❎
# Memoria RAM.
#
#
# ¡Alternativa incorrecta! Esta respuesta no corresponde.

# %% [markdown]
# ### 🏗️🧱✉️🔒 🚫 🛑<font color=green size=6>🏗️🧱✉️🔒 🚫 🛑**3.10 Haga lo que hicimos en aula**</font>
# ***

# %% [markdown]
# Llegó la hora de que sigas todos los pasos realizados por mí durante esta clase. Si ya lo has hecho ¡Excelente! Si todavía no lo has hecho, es importante que ejecutes lo que fue visto en los vídeos para que puedas continuar con la próxima aula.
#
# 1) El Hub presenta 2 limitaciones principalmente: El reenvía las PDUs a todos los dispositivos de la red resultando en lentitud y, además, si un usuario malicioso está conectado a la red, puede conocer el intercambio de información utilizando una aplicación de Análisis de Protocolos como Wireshark, por ejemplo, comprometiendo la seguridad de la red.
#
# 2) Veamos un ejemplo práctico utilizando Wireshark. Ejecutamos Wireshark y seleccionamos la interfaz por la cual estamos accediendo a internet. En mi caso particular, estoy usando la tarjeta de red de WiFi:
#
# 35.png
#
# 3) Al seleccionar la interfaz, se abrirá el analizador de protocolos, y mostrará todas las PDUs que están transitando por nuestra red. Visualizarás una serie de PDUs aumentando de forma gradual, muy rápidamente, dependiendo de la cantidad de consultas a internet que estén en curso:
#
# 36.png
#
# 4) En la parte superior izquierda, hay un botón de Stop, para detener las capturas de tráfico, lo debes presionar, y así detendrás el analizador:
#
# 37.png
#
# 5) Ahora, abre una nueva ventana del navegador que uses, y digita la siguiente URL: centraldeajuda.globo.com/Globoplay/:
#
# 38.png
#
# 6) Se trata de una página que no es segura, como lo indica el propio navegador, y vamos a digitar en el recuadro que dice como podemos ajudar? la palabra: bitcoin (No presiones enter todavía):
#
# 39.png
#
# 7) Vuelve a Wireshark, presiona la aleta del tiburón para iniciar una nueva captura, aparecerá un cuadro de diálogo preguntando si deseas almacenar la captura anterior; le dices que no haciendo clic en Continue without saving. E inicias una nueva captura. Vuelve al navegador, y ahora sí presiona enter:
#
# 40.png
#
# 41.png
#
# 8) Vuelve rápidamente a Wireshark y detienes la captura con el botón de Stop.
#
# 42.png
#
# 9) Ahora, vamos a reconstruir la PDU que contiene la información que consultamos en una página web no segura. Seleccionamos un paquete TCP, le damos clic derecho, y seleccionamos Follow TCP stream.
#
# 43.png
#
# 10) Al reconstruir todo el flujo de TCP, aparece algo semejante a:
#
# 44.png
#
# 11) En la primera línea aparece bitcoin:
#
# 45.png
#
# 12) Si hay un usuario malicioso conectado a la red, tendrá conocimiento de lo que estoy consultando, lo cual coloca en riesgo la seguridad de mi información. Esto sucede porque la página que seleccionamos no es segura:
#
# 46.png
#
# 13) Siempre que vayamos a colocar información en internet debemos cerciorarnos que estamos navegando en una página segura con Secure Socket Layer (SSL) , o por lo menos algún protocolo de seguridad semejante:
#
# 47.png
#
# Observación: Si la página es segura, aparecerá siempre un candado al lado izquierdo del campo donde digitamos las URLs, es decir, donde colocamos las páginas web que deseamos consultar.
#
# 14) Para evitar problemas de seguridad y lentitud en la red, hay un dispositivo llamado Switch que aprende y almacena las direcciones MAC de los dispositivos conectados en su red con los respectivos puertos de conexión. Así el switch envía la información únicamente a los usuarios involucrados en la comunicación. En Packet Tracer vamos a sustituir el Hub por un switch 2960-24TT y vamos a hacer la simulación paso a paso del recorrido de las PDUs que viajan por la red.
#
# 48.png
#
# 15) ¡Excelente! Ahora que conoces las principales diferencias entre el Switch y el Hub, ¿Cuál de estos dos dispositivos consideras más rápido y seguro en una red?
#
# Ver opinión del instructor
# Opinión del instructor
#
# Continúa con tus estudios, y en caso de dudas, no olvides acudir a nuestro foro.

# %% [markdown]
# ### 📄 📨 🚦⬆️⬇️ <font color=green size=6>📄 📨 🚦⬆️⬇️ **3.11 Lo que aprendimos**</font>
# ***

# %% [markdown]
# Lo que aprendimos en esta aula:
#
# - Las limitaciones del Hub.
# - A utilizar Wireshark.
# - A reconocer páginas web seguras.
# - A utilizar Switches.

# %% [markdown]
# #CAMBIAR
