# %% [markdown]
# <a href="https://colab.research.google.com/github/ahcamachod/2145-data-science-probando-relaciones-con-regresion-lineal/blob/proyecto-final/precios_de_inmuebles_regresion_lineal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***
# #🐧 <font color=#56B4E9 size=6>**Articulo_1: DevOps: una guía para la cultura de desarrollo y operaciones**</font>
# ***

# %% [markdown]
# El articulo completo se encuentra en el siguiente enlace:
#
# [DevOps: una guía para la cultura de desarrollo y operaciones](https://www.aluracursos.com/blog/devops-una-guia-sobre-cultura-del-desarrollo-y-operaciones)

# %% [markdown]
# ***
# #🐧 <font color=#56B4E9 size=6>**Articulo_2: Nube: qué es, historia y guía de la computación en la nube**</font>
# ***

# %% [markdown]
# El articulo completo se encuentra en el siguiente enlace:
#
# [Nube: qué es, historia y guía de la computación en la nube](https://www.aluracursos.com/blog/cloud-historia-y-guia-de-la-computacion-en-la-nube)

# %% [markdown]
# ***
# #🌐🖧🏠 🔗📡<font color=#56B4E9 size=6>🌐🖧🏠 🔗📡**Redes: Introducción, Conceptos y Práctica**</font>
# ***

# %% [markdown]
# ## 🖥️🖨️🖲️ 🛜 🔌 📶 <font color=green size=6> 🖥️🖨️🖲️ 🛜 🔌 📶**5.Direccionamiento IP y DHCP**</font>
# ***

# %% [markdown]
# ### 📄 📨 🚦⬆️⬇️ <font color=green size=6>📄 📨 🚦⬆️⬇️ **5.1 Preparando el ambiente**</font>
# ***

# %% [markdown]
# Para que puedas acompañar mejor el curso y los videos te lo dejamos acá las diapositivas [dejamos acá las diapositiva](C:\Users\Leonard E Espejo M\Downloads\ORACLE TECH ADVANCE\Ruta hacia la certificación OCI Foundations Associate - ONE\Redes Introducción Conceptos y Práctica), para que si necesites las tenga para bajar. Haga clic en diapositivas y tendrás para visualizar o bajarlas.
#
# [dejamos acá las diapositiva](C:\Users\Leonard E Espejo M\Downloads\ORACLE TECH ADVANCE\Ruta hacia la certificación OCI Foundations Associate - ONE\Redes Introducción Conceptos y Práctica)

# %%
from IPython.display import IFrame

# Cambia la ruta al PDF que quieres mostrar
IFrame('/content/Redes-1.pdf', width=700, height=500)
# Out:
#         <iframe
#             width="700"
#             height="500"
#             src="/content/Redes-1.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from google.colab import drive
drive.mount('/content/Redes-1.pdf')

# %% [markdown]
# ### 🏗️🧱✉️🔒 🚫 🛑<font color=green size=6>🏗️🧱✉️🔒 🚫 🛑**5.2 Direccionamiento IP**</font>
# ***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 📄 📨 🚦⬆️⬇️ <font color=green size=6>📄 📨 🚦⬆️⬇️ **5.3 Clases de IP**</font>
# ***

# %% [markdown]
# ¿Cuáles son las clases de direcciones IP que pueden ser empleadas para máquinas?
# <br />
# ✅
#
# Alternativa correta
#
# A, B y C.
#
#
# ¡Alternativa correcta! Estas son las únicas clases de direcciones IPv4 que se utilizan con máquinas.

# %% [markdown]
# ¿Cuáles son las clases de direcciones IP que pueden ser empleadas para máquinas?
# <br />
# ❎
# Clases 1 y 2.
#
#
# ¡Alternativa incorrecta! Estas clases no se relacionan con direcciones IP.

# %% [markdown]
# ¿Cuáles son las clases de direcciones IP que pueden ser empleadas para máquinas?
# <br />
# ❎
# A, B y D.
#
#
# ¡Alternativa incorrecta! Las direcciones clase D son para investigación y desarrollo y no se utilizan en máquinas.

# %% [markdown]
# ### 🏗️🧱✉️🔒 🚫 🛑<font color=green size=6>🏗️🧱✉️🔒 🚫 🛑**5.4 IP Privada**</font>
# ***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# TREDUCCIOM IP PRIVADA A IP PUBLICA ATRAVEZ DE NAT

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 📄 📨 🚦⬆️⬇️ <font color=green size=6>📄 📨 🚦⬆️⬇️ **5.5 IP Privado**</font>
# ***

# %% [markdown]
# ¿Qué son las direcciones IP privadas?
# <br />
# ✅
#
# Son IPs utilizados únicamente para la comunicación en la red local, no se puede acceder a internet con ellas.
#
#
# ¡Alternativa correcta! Así es.

# %% [markdown]
# ¿Qué son las direcciones IP privadas?
# <br />
# ❎
# Son IPs compradas por grandes empresas; solamente ellas las pueden usar.
#
#
# ¡Alternativa incorrecta! Esta definición no corresponde.

# %% [markdown]
# ¿Qué son las direcciones IP privadas?
# <br />
# ❎
# Son IPs usados en el internet solamente.
#
#
# ¡Alternativa incorrecta! Esta definición corresponde a las direcciones IP públicas.

# %% [markdown]
# ### 🏗️🧱✉️🔒 🚫 🛑<font color=green size=6>🏗️🧱✉️🔒 🚫 🛑**5.6 Servidor DHCP**</font>
# ***

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# red pcs sw y router
# TOPOLOGIA DE RED
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# CONFIGURACION ROUTER DHCP
#
#
#
# ```
# # Tiene formato de código
#
#          --- System Configuration Dialog ---
#
# Would you like to enter the initial configuration dialog? [yes/no]: N
#
#
# Press RETURN to get started!
#
#
#
# Router>enable
# Router#config
# Router#configure
# Configuring from terminal, memory, or network [terminal]? terminal
# Enter configuration commands, one per line.  End with CNTL/Z.
# Router(config)#inter
# Router(config)#interface fast
# Router(config)#interface fastEthernet 0/0
# Router(config-if)#no sh
# Router(config-if)#no shutdown
#
# Router(config-if)#
# %LINK-5-CHANGED: Interface FastEthernet0/0, changed state to up
#
# %LINEPROTO-5-UPDOWN: Line protocol on Interface FastEthernet0/0, changed state to up
#
# Router(config-if)#ip add
# Router(config-if)#ip address 192.168.0.1 255.255.255.0
# Router(config-if)#exit
# Router(config)#?
# Configure commands:
#   aaa                Authentication, Authorization and Accounting.
#   access-list        Add an access list entry
#   banner             Define a login banner
#   bba-group          Configure BBA Group
#   boot               Modify system boot parameters
#   cdp                Global CDP configuration subcommands
#   class-map          Configure Class Map
#   clock              Configure time-of-day clock
#   config-register    Define the configuration register
#   crypto             Encryption module
#   default            Set a command to its defaults
#   do                 To run exec commands in config mode
#   dot11              IEEE 802.11 config commands
#   enable             Modify enable password parameters
#   end                Exit from configure mode
#   exit               Exit from configure mode
#   flow               Global Flow configuration subcommands
#   hostname           Set system's network name
#   interface          Select an interface to configure
#   ip                 Global IP configuration subcommands
#   ipv6               Global IPv6 configuration commands
#   key                Key management
#   line               Configure a terminal line
#   lldp               Global LLDP configuration subcommands
#   logging            Modify message logging facilities
#   login              Enable secure login checking
#   mac-address-table  Configure the MAC address table
#   no                 Negate a command or set its defaults
#   ntp                Configure NTP
#   parameter-map      parameter map
#   parser             Configure parser
#   policy-map         Configure QoS Policy Map
#   port-channel       EtherChannel configuration
#   priority-list      Build a priority list
#   privilege          Command privilege parameters
#   queue-list         Build a custom queue list
#   router             Enable a routing process
#   secure             Secure image and configuration archival commands
#   security           Infra Security CLIs
#   service            Modify use of network based services
#   snmp-server        Modify SNMP engine parameters
#   spanning-tree      Spanning Tree Subsystem
#   tacacs-server      Modify TACACS query parameters
#   username           Establish User Name Authentication
#   vpdn               Virtual Private Dialup Network
#   vpdn-group         VPDN group configuration
#   zone               FW with zoning
#   zone-pair          Zone pair command
# Router(config)#ip ?
#   access-list       Named access-list
#   cef               Cisco Express Forwarding
#   default-gateway   Specify default gateway (if not routing IP)
#   default-network   Flags networks as candidates for default routes
#   dhcp              Configure DHCP server and relay parameters
#   domain            IP DNS Resolver
#   domain-lookup     Enable IP Domain Name System hostname translation
#   domain-name       Define the default domain name
#   flow-export       Specify host/port to send flow statistics
#   forward-protocol  Controls forwarding of physical and directed IP broadcasts
#   ftp               FTP configuration commands
#   host              Add an entry to the ip hostname table
#   inspect           Context-based Access Control Engine
#   ips               Intrusion Prevention System
#   local             Specify local options
#   name-server       Specify address of name server to use
#   nat               NAT configuration commands
#   route             Establish static routes
#   routing           Enable IP routing
#   scp               Scp commands
#   ssh               Configure ssh options
#   tcp               Global TCP parameters
# Router(config)#ip
# % Incomplete command.
# Router(config)#ip ?
#   access-list       Named access-list
#   cef               Cisco Express Forwarding
#   default-gateway   Specify default gateway (if not routing IP)
#   default-network   Flags networks as candidates for default routes
#   dhcp              Configure DHCP server and relay parameters
#   domain            IP DNS Resolver
#   domain-lookup     Enable IP Domain Name System hostname translation
#   domain-name       Define the default domain name
#   flow-export       Specify host/port to send flow statistics
#   forward-protocol  Controls forwarding of physical and directed IP broadcasts
#   ftp               FTP configuration commands
#   host              Add an entry to the ip hostname table
#   inspect           Context-based Access Control Engine
#   ips               Intrusion Prevention System
#   local             Specify local options
#   name-server       Specify address of name server to use
#   nat               NAT configuration commands
#   route             Establish static routes
#   routing           Enable IP routing
#   scp               Scp commands
#   ssh               Configure ssh options
#   tcp               Global TCP parameters
# Router(config)#ip dhcp
# % Incomplete command.
# Router(config)#ip dhcp
# % Incomplete command.
# Router(config)#ip dhcp ?
#   excluded-address  Prevent DHCP from assigning certain addresses
#   pool              Configure DHCP address pools
#   relay             DHCP relay agent parameters
# Router(config)#ip dhcp pool ?
#   WORD  Pool name
# Router(config)#ip dhcp pool
# % Incomplete command.
# Router(config)#
# Router(config)#ip dhcp pool ?
#   WORD  Pool name
# Router(config)#ip dhcp pool
# % Incomplete command.
# Router(config)#ip dhcp pool RED_LOCAL
# Router(dhcp-config)#ip dhcp pool RED_LOCAL
# Router(dhcp-config)#?
#   default-router  Default routers
#   dns-server      Set name server
#   domain-name     Domain name
#   exit            Exit from DHCP pool configuration mode
#   network         Network number and mask
#   no              Negate a command or set its defaults
#   option          Raw DHCP options
# Router(dhcp-config)#net
# Router(dhcp-config)#network 192.168.0.0
# % Incomplete command.
# Router(dhcp-config)#network 192.168.0.0 255.255.255.0
# Router(dhcp-config)#?
#   default-router  Default routers
#   dns-server      Set name server
#   domain-name     Domain name
#   exit            Exit from DHCP pool configuration mode
#   network         Network number and mask
#   no              Negate a command or set its defaults
#   option          Raw DHCP options
# Router(dhcp-config)#defa
# Router(dhcp-config)#default-router 192.168.0.1
# Router(dhcp-config)#exit
# Router(config)#
# Router#
# %SYS-5-CONFIG_I: Configured from console by console
#
# ```

# %% [markdown]
# PARA PC_1
#
#
#
# ```
# # Tiene formato de código
# C:\>IPCONFIG /ALL
#
# FastEthernet0 Connection:(default port)
#
#    Connection-specific DNS Suffix..:
#    Physical Address................: 00D0.D320.3811
#    Link-local IPv6 Address.........: FE80::2D0:D3FF:FE20:3811
#    IPv6 Address....................: ::
#    IPv4 Address....................: 192.168.0.2
#    Subnet Mask.....................: 255.255.255.0
#    Default Gateway.................: ::
#                                      192.168.0.1
#    DHCP Servers....................: 192.168.0.1
#    DHCPv6 IAID.....................:
#    DHCPv6 Client DUID..............: 00-01-00-01-95-D8-A0-A5-00-D0-D3-20-38-11
#    DNS Servers.....................: ::
#                                      0.0.0.0
#
# Bluetooth Connection:
#
#    Connection-specific DNS Suffix..:
#    Physical Address................: 0030.A363.D950
#    Link-local IPv6 Address.........: ::
#    IPv6 Address....................: ::
#    IPv4 Address....................: 0.0.0.0
#    Subnet Mask.....................: 0.0.0.0
#    Default Gateway.................: ::
#                                      0.0.0.0
#    DHCP Servers....................: 0.0.0.0
#    DHCPv6 IAID.....................:
#    DHCPv6 Client DUID..............: 00-01-00-01-95-D8-A0-A5-00-D0-D3-20-38-11
#    DNS Servers.....................: ::
#                                      0.0.0.0
#
#
# C:\>
# ```

# %% [markdown]
# PC_2
#
#
#
# ```
# # Tiene formato de código
# C:\>ipconfig /all
#
# FastEthernet0 Connection:(default port)
#
#    Connection-specific DNS Suffix..:
#    Physical Address................: 0060.2F49.CCDD
#    Link-local IPv6 Address.........: FE80::260:2FFF:FE49:CCDD
#    IPv6 Address....................: ::
#    IPv4 Address....................: 192.168.0.3
#    Subnet Mask.....................: 255.255.255.0
#    Default Gateway.................: ::
#                                      192.168.0.1
#    DHCP Servers....................: 192.168.0.1
#    DHCPv6 IAID.....................:
#    DHCPv6 Client DUID..............: 00-01-00-01-AC-19-B9-37-00-60-2F-49-CC-DD
#    DNS Servers.....................: ::
#                                      0.0.0.0
#
# Bluetooth Connection:
#
#    Connection-specific DNS Suffix..:
#    Physical Address................: 000A.417D.C749
#    Link-local IPv6 Address.........: ::
#    IPv6 Address....................: ::
#    IPv4 Address....................: 0.0.0.0
#    Subnet Mask.....................: 0.0.0.0
#    Default Gateway.................: ::
#                                      0.0.0.0
#    DHCP Servers....................: 0.0.0.0
#    DHCPv6 IAID.....................:
#    DHCPv6 Client DUID..............: 00-01-00-01-AC-19-B9-37-00-60-2F-49-CC-DD
#    DNS Servers.....................: ::
#                                      0.0.0.0
#
#
# C:\>
#
# ```

# %% [markdown]
# PC_3
#
#
#
# ```
# # Tiene formato de código
# C:\>ipconfig /all
#
# FastEthernet0 Connection:(default port)
#
#    Connection-specific DNS Suffix..:
#    Physical Address................: 0060.2F49.CCDD
#    Link-local IPv6 Address.........: FE80::260:2FFF:FE49:CCDD
#    IPv6 Address....................: ::
#    IPv4 Address....................: 192.168.0.3
#    Subnet Mask.....................: 255.255.255.0
#    Default Gateway.................: ::
#                                      192.168.0.1
#    DHCP Servers....................: 192.168.0.1
#    DHCPv6 IAID.....................:
#    DHCPv6 Client DUID..............: 00-01-00-01-AC-19-B9-37-00-60-2F-49-CC-DD
#    DNS Servers.....................: ::
#                                      0.0.0.0
#
# Bluetooth Connection:
#
#    Connection-specific DNS Suffix..:
#    Physical Address................: 000A.417D.C749
#    Link-local IPv6 Address.........: ::
#    IPv6 Address....................: ::
#    IPv4 Address....................: 0.0.0.0
#    Subnet Mask.....................: 0.0.0.0
#    Default Gateway.................: ::
#                                      0.0.0.0
#    DHCP Servers....................: 0.0.0.0
#    DHCPv6 IAID.....................:
#    DHCPv6 Client DUID..............: 00-01-00-01-AC-19-B9-37-00-60-2F-49-CC-DD
#    DNS Servers.....................: ::
#                                      0.0.0.0
#
#
# C:\>
#
# ```

# %% [markdown]
# PC PORTATIL
#
#
#
# ```
# # Tiene formato de código
#
# C:\>ipconfig /all
#
# FastEthernet0 Connection:(default port)
#
#    Connection-specific DNS Suffix..:
#    Physical Address................: 00E0.F907.127B
#    Link-local IPv6 Address.........: FE80::2E0:F9FF:FE07:127B
#    IPv6 Address....................: ::
#    IPv4 Address....................: 192.168.0.5
#    Subnet Mask.....................: 255.255.255.0
#    Default Gateway.................: ::
#                                      192.168.0.1
#    DHCP Servers....................: 192.168.0.1
#    DHCPv6 IAID.....................:
#    DHCPv6 Client DUID..............: 00-01-00-01-A9-5C-95-36-00-E0-F9-07-12-7B
#    DNS Servers.....................: ::
#                                      0.0.0.0
#
# Bluetooth Connection:
#
#    Connection-specific DNS Suffix..:
#    Physical Address................: 0001.97D5.B444
#    Link-local IPv6 Address.........: ::
#    IPv6 Address....................: ::
#    IPv4 Address....................: 0.0.0.0
#    Subnet Mask.....................: 0.0.0.0
#    Default Gateway.................: ::
#                                      0.0.0.0
#    DHCP Servers....................: 0.0.0.0
#    DHCPv6 IAID.....................:
#    DHCPv6 Client DUID..............: 00-01-00-01-A9-5C-95-36-00-E0-F9-07-12-7B
#    DNS Servers.....................: ::
#                                      0.0.0.0
#
#
# C:\>
#
# ```

# %% [markdown]
# PROBANDO PING DESDE EL PORTATIL
#
#
#
# ```
# # Tiene formato de código
# C:\>
# C:\>ping 192.168.0.1
#
# Pinging 192.168.0.1 with 32 bytes of data:
#
# Reply from 192.168.0.1: bytes=32 time=42ms TTL=255
# Reply from 192.168.0.1: bytes=32 time=3ms TTL=255
# Reply from 192.168.0.1: bytes=32 time=3ms TTL=255
# Reply from 192.168.0.1: bytes=32 time=3ms TTL=255
#
# Ping statistics for 192.168.0.1:
#     Packets: Sent = 4, Received = 4, Lost = 0 (0% loss),
# Approximate round trip times in milli-seconds:
#     Minimum = 3ms, Maximum = 42ms, Average = 12ms
#
# C:\>
#
# ```

# %% [markdown]
# ### 📄 📨 🚦⬆️⬇️ <font color=green size=6>📄 📨 🚦⬆️⬇️ **5.7 El servidor DHCP**</font>
# ***

# %% [markdown]
# ¿Para qué sirve un servidor DHCP?
# <br />
# ✅
#
# Para atribuir IPs a máquinas (clientes) de forma dinámica.
#
#
# ¡Alternativa correcta! Los servidores de configuración dinámica de clientes DHCP permiten asignar de manera “dinámica” las direcciones IP a los clientes.

# %% [markdown]
# ¿Para qué sirve un servidor DHCP?
# <br />
# ❎
# Para contrabalancear el tráfico en un router.
#
#
# ¡Alternativa incorrecta! Esta definición no corresponde.

# %% [markdown]
# ¿Para qué sirve un servidor DHCP?
# <br />
# ❎
# Para traducir direcciones IP en URLs.
#
#
# ¡Alternativa incorrecta! Esta es la función del servidor DNS.

# %% [markdown]
# ### 🏗️🧱✉️🔒 🚫 🛑<font color=green size=6>🏗️🧱✉️🔒 🚫 🛑**5.8 Solicitud de IP**</font>
# ***

# %% [markdown]
# Cuando un cliente no posee una dirección IP y está configurado para recibir su IP dinámica, ¿Cómo hace la solicitud para que algún equipo le asigne una dirección IP?
# <br />
# ✅Broadcast
#
#
# ¡Alternativa correcta! Así es; el computador necesita preguntarle a todos los equipos de la red para descubrir si alguno de ellos le puede ofrecer la dirección IP de forma dinámica. Esta comunicación desde un equipo hacia todos los demás equipos de la red se conoce como Broadcast.

# %% [markdown]
# Cuando un cliente no posee una dirección IP y está configurado para recibir su IP dinámica, ¿Cómo hace la solicitud para que algún equipo le asigne una dirección IP?
# <br />
# ❎
# Unicast
#
#
# ¡Alternativa incorrecta! Esta respuesta no corresponde.

# %% [markdown]
# Cuando un cliente no posee una dirección IP y está configurado para recibir su IP dinámica, ¿Cómo hace la solicitud para que algún equipo le asigne una dirección IP?
# <br />
# ❎
# Multicast
#
#
# ¡Alternativa incorrecta! Esta respuesta no corresponde.

# %% [markdown]
# ### 📄 📨 🚦⬆️⬇️ <font color=green size=6>📄 📨 🚦⬆️⬇️ **5.9 Haga lo que hicimos en aula**</font>
# ***

# %% [markdown]
# Llegó la hora de que sigas todos los pasos realizados por mí durante esta clase. Si ya lo has hecho ¡Excelente! Si todavía no lo has hecho, es importante que ejecutes lo que fue visto en los vídeos para que puedas continuar con la próxima aula.
#
# 1. Vamos a configurar el servidor DHCP. Para ello, en Packet Tracer conectaremos 4 computadores a un Switch 2960 y el Switch a un Router 1841.En todas estas conexiones utilizaremos cables directos:
# 58.png
#
# 2.En Packet Tracer, no es necesario conectar un Computador a un Router a través del cable de consola, como lo hicimos en el aula anterior, para configurar los equipos. Basta hacer click sobre el Router y seleccionar la pestaña CLI:
# 59.png
#
# 3. Ahora, la secuencia de comandos que emplearemos es la siguiente:
#
# ```
# # Tiene formato de código
#
# n
# Router> enable
# Router# configure terminal
# Router(config)# interface fastEthernet 0/0
# Router(config-if)# ip address 192.168.0.1 255.255.255.0
# Router(config-if)# no shutdown
# Router(config-if)# exit
# Router(config)# ip dhcp pool RED_LOCAL
# Router(dhcp-config)# network 192.168.0.0 255.255.255.0
# Router(dhcp-config)# default-router 192.168.0.1
# Router(dhcp-config)# exit
# ```
#
# 4. Finalmente, en cada uno de los computadores, en el ícono de IP Configuration, seleccionaremos DHCP:
# 60.png
#
# 61.png
#
# 62.png
#
# 63.png
#
# 5. Las direcciones IP fueron asignadas de forma dinámica desde el Router ya que configuramos el servidor DHCP. ¿Qué sucede al hacer ping entre los diferentes dispositivos finales?
# Ver opinión del instructor
# - **Opinión del instructor**
#
# Continúa con tus estudios, y en caso de dudas, no olvides acudir a nuestro foro.

# %% [markdown]
# #CAMBIAR
